# %% [markdown]
# <a href="https://colab.research.google.com/github/omniaghazy/Mastering-python/blob/main/session1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Syntax And Your First App

# %%
print("Omnia")
# Out:
# Omnia

# %%
print("Omnia") ; print("Ghazy")
# Out:
# Omnia
# Ghazy

# %%
print("Omnia Ghazy" ,end=" ")
print("new")
# Out:
# Omnia Ghazy new

# %%
print("Omnia Ghazy" )
print("new")
# Out:
# Omnia Ghazy
# new

# %%
print("This ia a comment by  ctrl+/ " )
# commnet
# Out:
# This ia a comment by  ctrl+/

# %% [markdown]
# # Dealing With Data in Python

# %%
# type() = type of this data or variable
# all data type is object
# int
# float
# string
# list [] as array
# tuple ()
# dictionary{key : value}
# boolean

# %%
print("Omnia")
# Out:
# Omnia

# %%
print(type("omnia"))
# Out:
# <class 'str'>

# %%
print(type(print()))
# Out:
# <class 'NoneType'>

# %%
print(10)
# Out:
# 10

# %%
print(type(10))
# Out:
# <class 'int'>

# %%
print(type(-10))
# Out:
# <class 'int'>

# %%
print(type(100000000000000000))
# Out:
# <class 'int'>

# %%
print(type(1.0))
# Out:
# <class 'float'>

# %%
print(type(true))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_4384/61652065.py in <cell line: 0>()
# ----> 1 print(type(true))
#
# NameError: name 'true' is not defined

# %%
print(type(True))
# Out:
# <class 'bool'>

# %%
print(type([]))
# Out:
# <class 'list'>

# %%
print(type(()))
# Out:
# <class 'tuple'>

# %%
print(type({}))
# Out:
# <class 'dict'>

# %% [markdown]
# # Variables
